# %%
# from faker import Faker
# local_providers = ['ar_EG', 'ar_PS', 'ar_SA', 'bg_BG', 'bs_BA', 'cs_CZ', 'de_DE', 'dk_DK', 'el_GR', 'en_AU', 'en_CA', 'en_GB', 'en_IN', 'en_NZ', 'en_US', 'es_ES', 'es_MX', 'et_EE', 'fa_IR', 'fi_FI', 'fr_FR', 'hi_IN', 'hr_HR', 'hu_HU', 'hy_AM', 'it_IT', 'ja_JP', 'ka_GE', 'ko_KR', 'lt_LT', 'lv_LV', 'ne_NP', 'nl_NL', 'no_NO', 'pl_PL', 'pt_BR', 'pt_PT', 'ro_RO', 'ru_RU', 'sl_SI', 'sv_SE', 'tr_TR', 'uk_UA', 'zh_CN', 'zh_TW']
# language = ['Arabic', 'Arabic', 'Arabic', 'Bulgarian', 'Bosnian', 'Czech', 'German', 'Danish', 'Greek', 'English', 'English', 'English', 'English', 'English', 'English', 'Spanish', 'Spanish', 'Estonian', 'Persian', 'Finnish', 'French', 'Hindi', 'Croatian', 'Hungarian', 'Armenian', 'Italian', 'Japanese', 'Georgian', 'Korean', 'Lithuanian', 'Latvian', 'Nepali', 'Dutch', 'Norwegian', 'Polish', 'Portuguese', 'Portuguese', 'Romanian', 'Russian', 'Slovene', 'Swedish', 'Turkish', 'Ukranian', 'Chinese', 'Chinese']
# country = ['Egypt', 'Palestine', 'Saudi Arabia', 'Bulgaria', 'Bosnia', 'Czech Republic', 'Germany', 'Denmark', 'Greece', 'Australia', 'Canada', 'Great Britain', 'India', 'India', 'New Zealand', 'United States', 'Spain', 'Mexico', 'Estonian', 'Iran', 'Finnish', 'French', 'Hindi', 'Croatia', 'Hungary', 'Armenia', 'Italy', 'Japan', 'Georgia', 'South Korea', 'Lithuania', 'Latvia', 'Nepal', 'Netherlands', 'Norway', 'Brazil', 'Portugal', 'Romania', 'Russia', 'Slovakia', 'Sweden', 'Turkey', 'Ukraine', 'China', 'Taiwan']
# first_names = []
# last_names = []
# full_names = []
# arr_lang = []
# lang_cd = []
# arr_country = []

# for i in range(len(local_providers)):
#     fake = Faker([local_providers[i]])
#     for j in range(1000):
#         name = fake.name().split(' ')
#         first_names.append(name[0])
#         if (len(name) > 1):
#             last_names.append(name[1])
#         else:
#             last_names.append('')
#         full_names.append(name)
#         arr_lang.append(language[i])
#         lang_cd.append(local_providers[i].split('_')[0])
#         arr_country.append(country[i])
# df_names = pd.DataFrame({'first_name': first_names, 'last_name': last_names, 'full_name': full_names, 'language': arr_lang, 'language_code': lang_cd,'country': arr_country})

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('spotify_dataset/data.csv')

# %%
df.sample(10)
# Out:
#         acousticness                                            artists  \
# 67941         0.4800                                ['The Brady Bunch']
# 139098        0.0468                      ['Steve Stills', 'Al Kooper']
# 31378         0.1060  ['Anthony Brown & group therAPy', 'Group Thera...
# 49431         0.7670                                ['Ella Fitzgerald']
# 142132        0.0248                                         ['Eminem']
# 151008        0.1310                                            ['D12']
# 60614         0.1060                               ['The Halo Benders']
# 98682         0.8650                ['Bunny Berigan and His Orchestra']
# 152206        0.6770                                   ['Jack Johnson']
# 163730        0.9260                        ['The Percy Faith Strings']
#
#         danceability  duration_ms  energy  explicit                      id  \
# 67941          0.563       151600  0.5970         0  54A2fwls8Nr4ljsytz0UP9
# 139098         0.530       667760  0.5440         0  7Dz6chaHT4z511PPLUYSCt
# 31378          0.630       257093  0.9000         0  37PMWc1U9QTGRSh9cKzvDj
# 49431          0.572       143160  0.5250         0  01eQIOIzFxetNf2t59xF5f
# 142132         0.838       211893  0.7130         1  2SvgBb7Wxa9ZfeamgGIGZl
# 151008         0.730       334600  0.4960         1  05v6w9fcXfhRjdcV3MxHFG
# 60614          0.633       218573  0.9220         0  1fcZq96QZkAkEHcC1FlH9l
# 98682          0.712       203333  0.0789         0  3Lt1LmMg1DtS5n2mUA3Fmb
# 152206         0.717       242747  0.4500         0  2uRz1DAgAuK7CObjr1Lepu
# 163730         0.169       197653  0.2980         0  4l1bdE4tCuuSvQRJ4d2jxJ
#
#         instrumentalness  key  liveness  loudness  mode  \
# 67941           0.000000    8    0.2500    -7.711     1
# 139098          0.000670    2    0.4120    -8.721     1
# 31378           0.000000    2    0.3310    -5.548     1
# 49431           0.000000    5    0.9150    -4.721     0
# 142132          0.000002   11    0.1210    -7.062     0
# 151008          0.000000    9    0.0982    -6.538     1
# 60614           0.000023    9    0.0317    -8.285     0
# 98682           0.833000   10    0.0518   -14.397     1
# 152206          0.001020   11    0.1050    -8.531     1
# 163730          0.918000    5    0.1170   -15.438     1
#
#                                                      name  popularity  \
# 67941                                 It's A Sunshine Day          30
# 139098                                Season of the Witch          33
# 31378                                           Testimony          47
# 49431   Lullaby Of Birdland - Live At The Newport Jazz...           9
# 142132                                          I'm Shady          51
# 151008                                              Girls          51
# 60614                               Don't Touch My Bikini          33
# 98682                                    Jelly-Roll Blues           0
# 152206                                         Never Fade          53
# 163730                                            Bouquet          20
#
#        release_date  speechiness    tempo  valence  year
# 67941    1993-01-01       0.0460  138.300   0.7770  1993
# 139098         1968       0.0463   83.203   0.5790  1968
# 31378    2012-08-21       0.2320  165.923   0.7690  2012
# 49431    1958-01-01       0.0974  129.109   0.8580  1958
# 142132   1999-02-23       0.2540   92.904   0.7090  1999
# 151008   2001-01-01       0.3080   82.418   0.2250  2001
# 60614    1994-06-28       0.0475  117.879   0.9640  1994
# 98682          1934       0.0465  103.993   0.5030  1934
# 152206   2013-01-01       0.0504   73.990   0.5710  2013
# 163730         1959       0.0336   83.542   0.0585  1959
